# %%
import pandas as pd

# %%
# Open Csv file in local machine
df=pd.read_csv('placement.csv')

# %%
# # Read csv file in url 
# import requests
# import csv
# from io import StringIO

# url = "https://example.com/data.csv"
# response = requests.get(url)
# response.raise_for_status()  # Ensure we notice bad responses

# csv_data = StringIO(response.text)
# reader = csv.reader(csv_data)

# %%
# Read tsv file 
df=pd.read_csv('titanic.tsv',sep='\t')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                               Heikkinen, Miss. Laina  female  26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                             Allen, Mr. William Henry    male  35      0
# ..                                                 ...     ...  ..    ...
# ...

# %%
# Header Parameter
df=pd.read_csv('placement.csv',header=1)
df
# Out:
#      0  6.8  123.0  1
# 0    1  5.9  106.0  0
# 1    2  5.3  121.0  0
# 2    3  7.4  132.0  1
# 3    4  5.8  142.0  0
# 4    5  7.1   48.0  1
# ..  ..  ...    ... ..
# 94  95  4.3  200.0  0
# 95  96  4.4   42.0  0
# 96  97  6.7  182.0  1
# 97  98  6.3  103.0  1
# 98  99  6.2  113.0  1
#
# [99 rows x 4 columns]

# %%
# use column Parameter
df=pd.read_csv('a.csv',usecols=['Industry_aggregation_NZSIOC','Industry_code_NZSIOC'])
df
# Out:
#       Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0                         Level 1                99999
# 1                         Level 1                99999
# 2                         Level 1                99999
# 3                         Level 1                99999
# 4                         Level 1                99999
# ...                           ...                  ...
# 50980                     Level 3                 ZZ11
# 50981                     Level 3                 ZZ11
# 50982                     Level 3                 ZZ11
# 50983                     Level 3                 ZZ11
# 50984                     Level 3                 ZZ11
#
# [50985 rows x 2 columns]

# %%
# Squeeze Parameter
pd.read_csv('a.csv',usecols=['Units'],squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Squeeze Parameter
# ----> 2 pd.read_csv('a.csv',usecols=['Units'],squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
# nrow parametter
pd.read_csv('a.csv',nrows=100)
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2023                     Level 1                99999
# 1   2023                     Level 1                99999
# 2   2023                     Level 1                99999
# 3   2023                     Level 1                99999
# 4   2023                     Level 1                99999
# ..   ...                         ...                  ...
# 95  2023                     Level 4                AA111
# 96  2023                     Level 4                AA111
# 97  2023                     Level 4                AA111
# 98  2023                     Level 4                AA111
# 99  2023                     Level 4                AA111
#
#               Industry_name_NZSIOC               Units Variable_code  \
# 0                   All industries  Dollars (millions)           H01
# 1                   All industries  Dollars (millions)           H04
# ...

# %%
# Encoding Parameter
pd.read_csv('a.csv',encoding='latin=1')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# Skip bad line 
pd.read_csv('a.csv',sep=';',encoding='latin=1')
# Out:
#       Year,Industry_aggregation_NZSIOC,Industry_code_NZSIOC,Industry_name_NZSIOC,Units,Variable_code,Variable_name,Variable_category,Value,Industry_code_ANZSIC06
# 0      2023,Level 1,99999,All industries,Dollars (mil...
# 1      2023,Level 1,99999,All industries,Dollars (mil...
# 2      2023,Level 1,99999,All industries,Dollars (mil...
# 3      2023,Level 1,99999,All industries,Dollars (mil...
# 4      2023,Level 1,99999,All industries,Dollars (mil...
# ...                                                  ...
# 50980  2013,Level 3,ZZ11,Food product manufacturing,P...
# 50981  2013,Level 3,ZZ11,Food product manufacturing,P...
# 50982  2013,Level 3,ZZ11,Food product manufacturing,P...
# 50983  2013,Level 3,ZZ11,Food product manufacturing,P...
# 50984  2013,Level 3,ZZ11,Food product manufacturing,P...
#
# [50985 rows x 1 columns]

# %%
# # dtype Parameter 
# # column datatype converter.
# pd.read_csv('a.csv',dtype={'Value':float}).info()

# %%
#Convert name 
def rename(name):
    if name=='Financial performance':
        return 'FP'
    else:
        return name
    
# now apply it 

pd.read_csv('a.csv',converters={'Variable_category':rename})
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# Nan_values Paramter
pd.read_csv('a.csv',na_values=['name'])
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# loading Huge dataset chunks
df=pd.read_csv('a.csv',chunksize=5000)

# %%
for chaunk in df:
    print(chaunk.shape)
# Out:
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (5000, 10)
# (985, 10)
