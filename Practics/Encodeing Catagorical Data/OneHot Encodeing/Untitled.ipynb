# %%
import pandas as pd

# %%
df=pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df['brand'].unique
# Out:
# <bound method Series.unique of 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: brand, Length: 8128, dtype: object>

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
# One hot Encodeing with pandas

# %%
# create Multicollinearity problem 
pd.get_dummies(df,columns=['fuel','owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %%
# K-1 One hot Encodeing 
# solve Multicollinearity problem
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
# ...

# %%
# One hot Encodeing use sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,0:4], df.iloc[0:,-1], test_size=0.2,random_state=25)

# %%
x_test.head()
# Out:
#         brand  km_driven    fuel         owner
# 4799      BMW      30000  Diesel   First Owner
# 1293     Ford     100000  Diesel  Second Owner
# 2351     Tata      10000  Petrol   First Owner
# 3374   Maruti      15000  Petrol   First Owner
# 349   Hyundai      40000  Petrol   First Owner

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(drop='first')

# %%
x_train_new=ohe.fit_transform(x_train[['fuel','owner']]).toarray()

# %%
x_test_new=ohe.fit_transform(x_test[['fuel','owner']]).toarray()

# %%
x_test_new.shape
# Out:
# (1626, 6)

# %%
# One hot Encodeing with Top catagoris

# %%
counts=df['brand'].value_counts()
counts
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df['brand'].nunique()
threshold=100

# %%
repl=counts[counts<=threshold].index
repl
# Out:
# Index(['Nissan', 'Jaguar', 'Volvo', 'Datsun', 'Mercedes-Benz', 'Fiat', 'Audi',
#        'Lexus', 'Jeep', 'Mitsubishi', 'Force', 'Land', 'Isuzu', 'Kia',
#        'Ambassador', 'Daewoo', 'MG', 'Ashok', 'Opel', 'Peugeot'],
#       dtype='object', name='brand')

# %%
pd.get_dummies(df['brand'].replace(repl,'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 7267  False      False  False  False    False      True   False    False
# 6898  False      False  False  False    False     False    True    False
# 1858  False      False  False  False    False     False   False    False
# 7261  False      False   True  False    False     False   False    False
# 8117  False      False  False  False    False     False    True    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 7267  False  False   False       False     False
# 6898  False  False   False       False     False
# 1858  False  False   False       False      True
# 7261  False  False   False       False     False
# 8117  False  False   False       False     False

# %%
### Now Realife Code:
# last 10 brand(low frequency) convert one brand.

# %%
# Brand Frequecny count
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
# last 10 brand select .
last_10_brand=count.tail(10).index

# %%
last_10_brand
# Out:
# Index(['Force', 'Land', 'Isuzu', 'Kia', 'Ambassador', 'Daewoo', 'MG', 'Ashok',
#        'Opel', 'Peugeot'],
#       dtype='object', name='brand')

# %%
# Now Replace dictionary create

replace_dict={brand:'Others' for brand in last_10_brand}

# Create new Columns
df['brand_updated']=df['brand'].replace(replace_dict)

# menually do it
replace_dict = {
    'Isuzu': 'অন্যান্য',
    'Kia': 'অন্যান্য',
    'Ambassador': 'অন্যান্য',
    'Daewoo': 'অন্যান্য',
    'MG': 'অন্যান্য',
    'Ashok': 'অন্যান্য',
    'Opel': 'অন্যান্য',
    'Peugeot': 'অন্যান্য',
    'Force': 'অন্যান্য',
    'Land': 'অন্যান্য'
}
#

# %%
# print update dataset
print(df[['brand','brand_updated']])
# Out:
#         brand brand_updated
# 0      Maruti        Maruti
# 1       Skoda         Skoda
# 2       Honda         Honda
# 3     Hyundai       Hyundai
# 4      Maruti        Maruti
# ...       ...           ...
# 8123  Hyundai       Hyundai
# 8124  Hyundai       Hyundai
# 8125   Maruti        Maruti
# 8126     Tata          Tata
# 8127     Tata          Tata
#
# [8128 rows x 2 columns]

# %% [raw]
# #update dataset csv file save

# %%
df.to_csv('final.csv',index=False)

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price brand_updated
# 0   Maruti     145500  Diesel   First Owner         450000        Maruti
# 1    Skoda     120000  Diesel  Second Owner         370000         Skoda
# 2    Honda     140000  Petrol   Third Owner         158000         Honda
# 3  Hyundai     127000  Diesel   First Owner         225000       Hyundai
# 4   Maruti     120000  Petrol   First Owner         130000        Maruti
