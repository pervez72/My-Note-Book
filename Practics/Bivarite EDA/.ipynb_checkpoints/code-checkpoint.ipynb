# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#### Single plot but present 5 multiple data varients, 2 relationship, and 3 type others
#### Scatter Plot 
#### Data Presentation Numerical-Numerical

# %%
sns.scatterplot(data=df,x="total_bill",y="tip",hue=df['sex'],style=df['smoker'],size=df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
